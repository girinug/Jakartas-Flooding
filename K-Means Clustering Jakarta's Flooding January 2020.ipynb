# %% [markdown]
# Data yang digunakan adalah data banjir pada bulan Januari 2020, dimana pada bulan tersebut Jakarta mengalami banjir hampir disebagian besar wilayahnya.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_awal = pd.read_csv("data_banjir_jakarta_2020_lengkap_baru.csv")

# %%
file_awal.head()
# Out:
#   kota_administrasi    kecamatan              kelurahan  \
# 0     Jakarta Pusat   Johar Baru             Johar Baru
# 1     Jakarta Pusat    Kemayoran  Gunung Sahari Selatan
# 2     Jakarta Pusat    Kemayoran                Serdang
# 3     Jakarta Pusat  Sawah Besar             Pasar Baru
# 4     Jakarta Pusat  Tanah Abang        Bendungan Hilir
#
#                               rw  jumlah_terdampak_rw  jumlah_terdampak_rt  \
# 0              RW 01, 02, 06, 08                    4                    4
# 1              RW 01, 02, 07, 08                    4                    4
# 2              RW 01, 02, 06, 07                    4                    4
# 3  RW 02, 03, 04, 05, 06, 07, 08                    7                    7
# 4                      RW 07, 09                    2                    2
#
#    jumlah_terdampak_kk  jumlah_terdampak_jiwa ketinggian_air  \
# 0                   35                    140   10 s/d 30 cm
# ...

# %%
file_awal.describe()
# Out:
#        jumlah_terdampak_rw  jumlah_terdampak_rt  jumlah_terdampak_kk  \
# count           262.000000           262.000000           262.000000
# mean              2.484733             3.832061            84.332061
# std               3.111860             6.416159           195.972084
# min               0.000000             0.000000             0.000000
# 25%               0.000000             0.000000             0.000000
# 50%               1.000000             1.000000             0.000000
# 75%               4.000000             5.000000            63.500000
# max              15.000000            38.000000          1140.000000
#
#        jumlah_terdampak_jiwa  ketinggian_air_terendah  \
# count             262.000000               262.000000
# mean              317.152672                19.335878
# std               720.394591                24.554298
# min                 0.000000                 0.000000
# 25%                 0.000000                 0.000000
# ...

# %%
file_awal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 262 entries, 0 to 261
# Data columns (total 21 columns):
# kota_administrasi             262 non-null object
# kecamatan                     262 non-null object
# kelurahan                     262 non-null object
# rw                            262 non-null object
# jumlah_terdampak_rw           262 non-null int64
# jumlah_terdampak_rt           262 non-null int64
# jumlah_terdampak_kk           262 non-null int64
# jumlah_terdampak_jiwa         262 non-null int64
# ketinggian_air                262 non-null object
# ketinggian_air_terendah       262 non-null int64
# ketinggian_air_tertinggi      262 non-null int64
# ketinggian_air_rata           262 non-null float64
# tanggal_kejadian              262 non-null object
# lama_genangan                 262 non-null int64
# jumlah_meninggal              262 non-null int64
# jumlah_hilang                 262 non-null int64
# jumlah_luka_berat             262 non-null int64
# ...

# %%
file = file_awal.loc[file_awal['ketinggian_air_rata'] != 0]
non_flood = file_awal.loc[file_awal['ketinggian_air_rata'] == 0]

# %% [markdown]
# Dari data yang ada, kemudian digunakan 3 parameter yaitu luasan yang diwakili oleh jumlah RT yang terdampak, ketinggian
# air yang diwakili oleh ketinggian air rata - rata dan korban bencana yang diwakili oleh jumlah jiwa yang terdampak. Untuk parameter waktu yang diwakili oleh lama genangan tidak digunakan karena tingkat keragaman data yang rendah

# %% [markdown]
# ## Clustering

# %%
new = file.filter(['jumlah_terdampak_rt','ketinggian_air_rata','jumlah_terdampak_jiwa'], axis=1)
new_data = new.copy()

# %%
new.head()
# Out:
#    jumlah_terdampak_rt  ketinggian_air_rata  jumlah_terdampak_jiwa
# 0                    4                 20.0                    140
# 1                    4                 40.0                      0
# 2                    4                 20.0                      0
# 3                    7                 40.0                    625
# 4                    2                 50.5                    195

# %%
from sklearn import preprocessing
from sklearn.decomposition import PCA
X_scaled = preprocessing.scale(new)
pca = PCA(n_components=2)
df = pca.fit_transform(X_scaled)
df = pd.DataFrame(df)

# %%
n_init = 10
max_iter = 300
tol = 0.0001
n_jobs = 2

plt.figure(figsize=(10, 8))
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42,n_init=n_init,
                   max_iter=max_iter,tol = tol,n_jobs=n_jobs)
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
n_clusters = 4
kmeans = KMeans(n_clusters = n_clusters, init = 'k-means++', random_state = 42,n_init=n_init,
                   max_iter=max_iter,tol = tol,n_jobs=n_jobs)
kmeans.fit(df)
y_kmeans = kmeans.predict(df)
centers = kmeans.cluster_centers_
plt.scatter(df.loc[:, 0], df.loc[:, 1], c=y_kmeans, s=50, cmap='viridis')
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5)
plt.show()

# %%
new['cluster'] =  pd.Series(y_kmeans)

# %%
new = new[['jumlah_terdampak_rt','ketinggian_air_rata','jumlah_terdampak_jiwa','cluster']]
new.head()
# Out:
#    jumlah_terdampak_rt  ketinggian_air_rata  jumlah_terdampak_jiwa  cluster
# 0                    4                 20.0                    140        0
# 1                    4                 40.0                      0        0
# 2                    4                 20.0                      0        0
# 3                    7                 40.0                    625        0
# 4                    2                 50.5                    195        0

# %%
num = new_data.columns[:]

def cl(n):
    value = []
    for i in num:
        value.append(new.loc[new['cluster']==n,:].describe().loc['mean',i])
    return value

# %%
num
# Out:
# Index(['jumlah_terdampak_rt', 'ketinggian_air_rata', 'jumlah_terdampak_jiwa'], dtype='object')

# %%
new.loc[new['cluster'] == 3, 'cluster'] = 4
new.loc[new['cluster'] == 2, 'cluster'] = 3
new.loc[new['cluster'] == 1, 'cluster'] = 2
new.loc[new['cluster'] == 0, 'cluster'] = 1

# %%
cluster_1 = cl(1)
cluster_2 = cl(2)
cluster_3 = cl(3)
cluster_4 = cl(4)

# %%
x = 0
w= 1
plt.figure(figsize=(15,9))
label = ['jumlah rt','ketinggian air','Jumlah warga terdampak']
for i in range(1,4):
    plt.subplot(2, 3, i)
    fig1 = plt.bar(x+1,cluster_1[i-1],color='y')
    fig2 = plt.bar(x+w+1,cluster_2[i-1],color='g')
    fig3 = plt.bar(x+3*w,cluster_3[i-1],color='r')
    fig4 = plt.bar(x+4*w,cluster_4[i-1],color='b')
    plt.title(label[i-1])
    plt.legend(['1','2','3','4'])
plt.savefig('graph1.png')
plt.show()

# %% [markdown]
# <p> Cluster 1 = Ringan. Terjadi pada area yang kecil (sekitar 5 RT), ketinggian air rata - rata berkisar 40 cm dan jumlah warga terdampak kurang dari 500 orang
# <p> Cluster 2 = Sedang. Terjadi pada area yang kecil (sekitar 5 RT), tinggian air rata - rata mencapai 100 cm dan jumlah warga yang terdampak kurang dari 500 orang
# <p> Cluster 3 = Sedang-Berat. Terjadi Pada area yang cukup luas yaitu lebih dari 10 RT dengan ketinggian air rata - rata mencapai 80 cm dengan jumlah rata - rata warga yang terdampak berkisar 1500 orang
# <p> Cluster 4 = Berat. Terjadi pada area yang sangat luas dengan sekitar 30 RT terendam banjir dengan ketinggian air rata - rata lebih dari 80 cm dan jumlah warga terdampak mencapai 3000 orang

# %%
new = new.filter(['cluster'], axis=1)
data_baru = pd.concat([file, non_flood],ignore_index=True)
data_baru = pd.concat([data_baru, new], axis=1)
data_baru.tail()
# Out:
#     kota_administrasi    kecamatan        kelurahan rw  jumlah_terdampak_rw  \
# 257     Jakarta Timur   Pulogadung      Pulo Gadung  0                    0
# 258     Jakarta Timur   Pulogadung  Jatinegara Kaum  0                    0
# 259     Jakarta Timur  Duren Sawit      Duren Sawit  0                    0
# 260     Jakarta Timur  Duren Sawit      Malaka Sari  0                    0
# 261     Jakarta Timur       Cakung      Pulo Gebang  0                    0
#
#      jumlah_terdampak_rt  jumlah_terdampak_kk  jumlah_terdampak_jiwa  \
# 257                    0                    0                      0
# 258                    0                    0                      0
# 259                    0                    0                      0
# 260                    0                    0                      0
# 261                    0                    0                      0
#
#     ketinggian_air  ketinggian_air_terendah  ...  tanggal_kejadian  \
# ...

# %%
data_baru['cluster'] = data_baru['cluster'].replace(np.nan, 0)

# %%
data_baru.tail()
# Out:
#     kota_administrasi    kecamatan        kelurahan rw  jumlah_terdampak_rw  \
# 257     Jakarta Timur   Pulogadung      Pulo Gadung  0                    0
# 258     Jakarta Timur   Pulogadung  Jatinegara Kaum  0                    0
# 259     Jakarta Timur  Duren Sawit      Duren Sawit  0                    0
# 260     Jakarta Timur  Duren Sawit      Malaka Sari  0                    0
# 261     Jakarta Timur       Cakung      Pulo Gebang  0                    0
#
#      jumlah_terdampak_rt  jumlah_terdampak_kk  jumlah_terdampak_jiwa  \
# 257                    0                    0                      0
# 258                    0                    0                      0
# 259                    0                    0                      0
# 260                    0                    0                      0
# 261                    0                    0                      0
#
#     ketinggian_air  ketinggian_air_terendah  ...  tanggal_kejadian  \
# ...

# %% [markdown]
# Penambahan Cluster 0 untuk kelurahan yang tidak mengalami banjir

# %%
data_baru.to_excel('cluster_banjir_jakarta.xlsx')
